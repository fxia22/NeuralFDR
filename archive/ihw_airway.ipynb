# %%
data = read.csv('data/data_1d_depend3.csv', head=TRUE)
library('IHW')

# %%
ihwRes <- ihw(p_value ~ x_value, data, alpha = 0.1)

# %%
rejections(ihwRes)
# Out:
# [1] 10382

# %%
plot(ihwRes)
# Out:
# plot without title

# %%
length(data$pvalue)
# Out:
# [1] 33469
