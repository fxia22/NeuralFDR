# %%
data = read.csv('data.csv', head=TRUE)

# %%
library("IHW")

# %%
ihwRes <- ihw(p_value ~ x_value ,  data = data, alpha = 0.05)

# %%
rejections(ihwRes)
# Out:
# [1] 458

# %%
plot(ihwRes)
# Out:
# plot without title
