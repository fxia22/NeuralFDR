# %%
load("mri.RData")

# %%
library("IHW")
ihw_res <- ihw(output$pval, covariates =  output$ROI_labels,  alpha = 0.2)

# %%
plot(ihw_res)
# Out:
# plot without title

# %%
rejections(ihw_res)
# Out:
# [1] 924
