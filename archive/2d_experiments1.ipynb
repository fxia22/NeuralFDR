# %%
from sideinfo import *
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# %%
for j in range(1,11):
    n_samples=100000
    p, h, x = generate_data_2D(data_vis=1,n_samples=n_samples)
    print("Num of alt: ", np.sum(h))
    print("True null prop: ", 1-np.sum(h)/n_samples)
    dic_BH, t_BH = BH(p)
    print("BH: num of dis, threshold:", dic_BH,t_BH)
    dic_SBH, t_SBH, pi0_SBH = Storey_BH(p)
    print("Storey_BH: num of dis, threshold, null esti", dic_SBH, t_SBH, pi0_SBH)
    plt.savefig('2d1.png')

    with open('../data_rep/data_2d_gm.csv.' + str(j), 'w') as f:
        f.write('x1, x2, p_value, h\n')
        for i in range(len(x)):
            f.write("{}, {}, {}, {}\n".format(x[i,0], x[i,1], p[i], h[i]))

            
    x_rest = np.random.rand(100000,3)
    x = np.concatenate([x, x_rest], axis = 1)
    with open('../data_rep/data_5d_gm.csv.' + str(j), 'w') as f:
        f.write('x1, x2, x3, x4, x5 p_value, h\n')
        for i in range(len(x)):
            f.write("{}, {}, {}, {}, {}, {}, {}\n".format(x[i,0], x[i,1], x[i,2], x[i,3], x[i,4], p[i], h[i]))
# Out:
# ('Num of alt: ', 22333.0)
# ('True null prop: ', 0.77666999999999997)
# ('BH: num of dis, threshold:', 6838, 0.0034170779704845861)
# ('Storey_BH: num of dis, threshold, null esti', 7748, 0.0049538599066703383, 0.78193333333333337)
# ('Num of alt: ', 22537.0)
# ('True null prop: ', 0.77463000000000004)
# ('BH: num of dis, threshold:', 7148, 0.0035727700594842247)
# ('Storey_BH: num of dis, threshold, null esti', 8067, 0.0051507714784644115, 0.78295000000000003)
# ('Num of alt: ', 22245.0)
# ('True null prop: ', 0.77754999999999996)
# ('BH: num of dis, threshold:', 6829, 0.0034135500611760907)
# ('Storey_BH: num of dis, threshold, null esti', 7747, 0.004924283187102428, 0.78651666666666664)
# ('Num of alt: ', 22363.0)
# ('True null prop: ', 0.77637)
# ('BH: num of dis, threshold:', 6759, 0.0033774721748368649)
# ('Storey_BH: num of dis, threshold, null esti', 7680, 0.004865074591750433, 0.78911666666666669)
# ('Num of alt: ', 22341.0)
# ('True null prop: ', 0.77659)
# ('BH: num of dis, threshold:', 6878, 0.0034362657425510029)
# ('Storey_BH: num of dis, threshold, null esti', 7821, 0.00498133838561521, 0.78381666666666672)
# ('Num of alt: ', 22282.0)
# ('True null prop: ', 0.77717999999999998)
# ('BH: num of dis, threshold:', 7018, 0.0035078152925623251)
# ('Storey_BH: num of dis, threshold, null esti', 7940, 0.0050295735423291172, 0.78925000000000001)
# ('Num of alt: ', 22334.0)
# ('True null prop: ', 0.77666000000000002)
# ('BH: num of dis, threshold:', 7004, 0.0035001030630248892)
# ('Storey_BH: num of dis, threshold, null esti', 7895, 0.0050265459822757949, 0.78506666666666669)
# ('Num of alt: ', 22259.0)
# ('True null prop: ', 0.77740999999999993)
# ('BH: num of dis, threshold:', 7087, 0.0035429811581101714)
# ('Storey_BH: num of dis, threshold, null esti', 7935, 0.0050586543794028391, 0.78423333333333334)
# ('Num of alt: ', 22572.0)
# ('True null prop: ', 0.77427999999999997)
# ('BH: num of dis, threshold:', 7054, 0.0035232769717035875)
# ('Storey_BH: num of dis, threshold, null esti', 7978, 0.005104058767387387, 0.78073333333333328)
# ('Num of alt: ', 22376.0)
# ('True null prop: ', 0.77624000000000004)
# ('BH: num of dis, threshold:', 6927, 0.0034618148006658011)
# ('Storey_BH: num of dis, threshold, null esti', 7749, 0.0049018376566641432, 0.79041666666666666)

# %%
x_rest = np.random.rand(100000,3)

# %%
x = np.concatenate([x, x_rest], axis = 1)

# %%
p_target = opt_threshold_multi(x, p, 10, intensity= 0.1)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x[:,0], x[:,1] , p_target, s = 3, alpha = 0.3)

# %%
network = get_network(num_layers = 10, dim = 5)
optimizer = optim.Adagrad(network.parameters(), lr = 0.01)

# %%
print(BH(p))
print(Storey_BH(p))
#p_target = np.ones(x.shape) * Storey_BH(p)[1]
loss_hist = train_network_to_target_p(network, optimizer, x, p_target, num_it = 1000, dim = 5)
# Out:
# (7102, 0.0035496270345102832)
# (7978, 0.0050749454747497438, 0.78600000000000003)
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-8f9dfae87e77> in <module>()
#       2 print(Storey_BH(p))
#       3 #p_target = np.ones(x.shape) * Storey_BH(p)[1]
# ----> 4 loss_hist = train_network_to_target_p(network, optimizer, x, p_target, num_it = 1000, dim = 5)
#
# /home/fei/Development/sideinfo_param/archive/sideinfo.pyc in train_network_to_target_p(network, optimizer, x, target_p, num_it, dim, cuda)
#     398
#     399         optimizer.zero_grad()
# --> 400         output = network.forward(x_input)
#     401
#     402         loss = l1loss(output, target)
#
# /home/fei/Development/sideinfo_param/archive/sideinfo.pyc in forward(self, x)
#     368
#     369         def forward(self, x):
# --> 370             x = self.layers(x)
#     371             x = 0.5 * scale * x
#     372             return x
#
# /home/fei/.local/lib/python2.7/site-packages/torch/nn/modules/module.pyc in __call__(self, *input, **kwargs)
#     204
#     205     def __call__(self, *input, **kwargs):
# --> 206         result = self.forward(*input, **kwargs)
#     207         for hook in self._forward_hooks.values():
#     208             hook_result = hook(self, input, result)
#
# /home/fei/.local/lib/python2.7/site-packages/torch/nn/modules/container.pyc in forward(self, input)
#      62     def forward(self, input):
#      63         for module in self._modules.values():
# ---> 64             input = module(input)
#      65         return input
#      66
#
# /home/fei/.local/lib/python2.7/site-packages/torch/nn/modules/module.pyc in __call__(self, *input, **kwargs)
#     204
#     205     def __call__(self, *input, **kwargs):
# --> 206         result = self.forward(*input, **kwargs)
#     207         for hook in self._forward_hooks.values():
#     208             hook_result = hook(self, input, result)
#
# /home/fei/.local/lib/python2.7/site-packages/torch/nn/modules/linear.pyc in forward(self, input)
#      52             return self._backend.Linear()(input, self.weight)
#      53         else:
# ---> 54             return self._backend.Linear()(input, self.weight, self.bias)
#      55
#      56     def __repr__(self):
#
# /home/fei/.local/lib/python2.7/site-packages/torch/nn/_functions/linear.pyc in forward(self, input, weight, bias)
#       8         self.save_for_backward(input, weight, bias)
#       9         output = input.new(input.size(0), weight.size(0))
# ---> 10         output.addmm_(0, 1, input, weight.t())
#      11         if bias is not None:
#      12             # cuBLAS doesn't support 0 strides in sger, so we can't use expand
#
# KeyboardInterrupt:

# %%
plt.plot(np.log(loss_hist))

# %%
#optimizer = optim.Adagrad(network.parameters(), lr = 0.01)
loss_hist, s, s2 = train_network(network, optimizer, x, p, num_it = 6000, dim = 2)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900

# %%
plt.plot(loss_hist)
print(s,s2, s2/s)
# Out:
# [autoreload of sideinfo failed: Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
#   File "sideinfo.py", line 187
#     pi1_grid =
#               ^
# SyntaxError: invalid syntax
# ]
# (Variable containing:
#  0.1394
# [torch.FloatTensor of size 1]
# , Variable containing:
# 1.00000e-03 *
#   6.7762
# [torch.FloatTensor of size 1]
# , Variable containing:
# 1.00000e-02 *
#   4.8619
# [torch.FloatTensor of size 1]
# )

# %%
n_samples = len(x)
x_input = Variable(torch.from_numpy(x.astype(np.float32).reshape(n_samples ,2)))
p_input = Variable(torch.from_numpy(p.astype(np.float32).reshape(n_samples ,1)))
output = network.forward(x_input)
pred = (p_input < output).data.numpy()
pred = pred[:,0].astype(np.float32)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x[:,0], x[:,1] , output.data.numpy(), s = 3, alpha = 0.3)

# %%
sum(pred)
# Out:
# 1400.0

# %%
x_input = Variable(torch.from_numpy(x.astype(np.float32).reshape(n_samples ,2)))
p_input = Variable(torch.from_numpy(p.astype(np.float32).reshape(n_samples ,1)))

output = network.forward(x_input) 
pred = (p_input < output).data.numpy()
pred = pred[:,0].astype(np.float32)

print("Num of alternatives:",np.sum(h))
print("Num of discovery:",np.sum(pred))
print("Num of true discovery:",np.sum(pred * h))
print("Actual FDR:", 1-np.sum(pred * h) / np.sum(pred))

# Visuaizing the rejection threshold
x_grid = np.arange(-1, 1, 1/100.0)
y_grid = np.arange(-1, 1, 1/100.0)
X_grid, Y_grid = np.meshgrid(x_grid, y_grid)

x_in = Variable(torch.from_numpy(
    np.concatenate([[X_grid.flatten()], [Y_grid.flatten()]]).T.astype(np.float32)))
out = network(x_in)
z = out.data.numpy().reshape(X_grid.shape)

print('Learned rejection threshold:')
plt.figure()
plt.pcolor(X_grid, Y_grid, z*0.1)
plt.colorbar()
plt.title('threshold')
plt.savefig('2d2.png')
# Out:
# ('Num of alternatives:', 2185.0)
# ('Num of discovery:', 1429.0)
# ('Num of true discovery:', 1330.0)
# ('Actual FDR:', 0.069279216235129448)
# Learned rejection threshold:

# %%
with open('data/data_2d_gm.csv', 'w') as f:
    f.write('x1, x2, p_value, h\n')
    for i in range(len(x)):
        f.write("{}, {}, {}, {}\n".format(x[i,0], x[i,1], p[i], h[i]))

# %%
x.shape
# Out:
# (100000, 2)

# %%
with open('../data/data_5d_gm.csv', 'w') as f:
    f.write('x1, x2, x3, x4, x5 p_value, h\n')
    for i in range(len(x)):
        f.write("{}, {}, {}, {}, {}, {}, {}\n".format(x[i,0], x[i,1], x[i,2], x[i,3], x[i,4], p[i], h[i]))

# %%
km = KMeans(n_clusters=20)

# %%
groups = km.fit_predict(x)

# %%
with open('../data/data_5d_gm_ihw.csv', 'w') as f:
    f.write('x1, x2, x3, x4, x5, p_value, group,  h\n')
    for i in range(len(x)):
        f.write("{}, {}, {}, {}, {}, {}, {}, {}\n".format(x[i,0], x[i,1], x[i,2], x[i,3], x[i,4], p[i], groups[i], h[i]))
