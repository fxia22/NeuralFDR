# %%
data = read.csv('data3.csv', head=TRUE)

# %%
library("IHW")

# %%
ihwRes <- ihw(p_value ~ x_value ,  data = data, alpha = 0.05)

# %%
rejections(ihwRes)
# Out:
# [1] 1557

# %%
plot(ihwRes)
# Out:
# plot without title
