# %%
from sideinfo import *
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# %%
n_samples=10000
p, h, x = generate_data_2D(data_vis=1,n_samples=n_samples, job = 1)
print("Num of alt: ", np.sum(h))
print("True null prop: ", 1-np.sum(h)/n_samples)
dic_BH, t_BH = BH(p)
print("BH: num of dis, threshold:", dic_BH,t_BH)
dic_SBH, t_SBH, pi0_SBH = Storey_BH(p)
print("Storey_BH: num of dis, threshold, null esti", dic_SBH, t_SBH, pi0_SBH)
plt.savefig('2d3.png')
# Out:
# ('Num of alt: ', 1991.0)
# ('True null prop: ', 0.80089999999999995)
# ('BH: num of dis, threshold:', 622, 0.0030830222866547736)
# ('Storey_BH: num of dis, threshold, null esti', 682, 0.0040657064325357768, 0.83550000000000002)

# %%
p_target = opt_threshold_multi(x, p, 10, intensity= 0.1)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x[:,0], x[:,1] , p_target, s = 3, alpha = 0.3)
ax.view_init(30, 60)

# %%
network = get_network(num_layers = 10, dim = 2)
optimizer = optim.Adagrad(network.parameters(), lr = 0.01)

# %%
print(BH(p))
print(Storey_BH(p))
#p_target = np.ones(x.shape) * Storey_BH(p)[1]
loss_hist = train_network_to_target_p(network, optimizer, x, p_target, num_it = 3000, dim = 2)
# Out:
# (562, 0.0028004907686589868)
# (613, 0.0037776662525661761, 0.80633333333333335)
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900

# %%
plt.plot(np.log(loss_hist))

# %%
#optimizer = optim.Adagrad(network.parameters(), lr = 0.01)
loss_hist, s, s2 = train_network(network, optimizer, x, p, num_it = 3000, dim = 2)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900

# %%
plt.plot(loss_hist)
print(s,s2, s2/s)
# Out:
# (Variable containing:
# 1.00000e-02 *
#   7.4173
# [torch.FloatTensor of size 1]
# , Variable containing:
# 1.00000e-03 *
#   3.7272
# [torch.FloatTensor of size 1]
# , Variable containing:
# 1.00000e-02 *
#   5.0250
# [torch.FloatTensor of size 1]
# )

# %%
n_samples = len(x)
x_input = Variable(torch.from_numpy(x.astype(np.float32).reshape(n_samples ,2)))
p_input = Variable(torch.from_numpy(p.astype(np.float32).reshape(n_samples ,1)))
output = network.forward(x_input)
pred = (p_input < output).data.numpy()
pred = pred[:,0].astype(np.float32)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x[:,0], x[:,1] , output.data.numpy(), s = 3, alpha = 0.3)

# %%
sum(pred)
# Out:
# 758.0

# %%
x_input = Variable(torch.from_numpy(x.astype(np.float32).reshape(n_samples ,2)))
p_input = Variable(torch.from_numpy(p.astype(np.float32).reshape(n_samples ,1)))

output = network.forward(x_input)
pred = (p_input < output).data.numpy()
pred = pred[:,0].astype(np.float32)

print("Num of alternatives:",np.sum(h))
print("Num of discovery:",np.sum(pred))
print("Num of true discovery:",np.sum(pred * h))
print("Actual FDR:", 1-np.sum(pred * h) / np.sum(pred))

# Visuaizing the rejection threshold
x_grid = np.arange(-1, 1, 1/100.0)
y_grid = np.arange(-1, 1, 1/100.0)
X_grid, Y_grid = np.meshgrid(x_grid, y_grid)

x_in = Variable(torch.from_numpy(
    np.concatenate([[X_grid.flatten()], [Y_grid.flatten()]]).T.astype(np.float32)))
out = network(x_in)
z = out.data.numpy().reshape(X_grid.shape)

print('Learned rejection threshold:')
plt.figure()
plt.pcolor(X_grid, Y_grid, z*0.1)
plt.colorbar()
plt.savefig('2d4.png')
# Out:
# ('Num of alternatives:', 2025.0)
# ('Num of discovery:', 752.0)
# ('Num of true discovery:', 713.0)
# ('Actual FDR:', 0.051861702127659615)
# Learned rejection threshold:

# %%
with open('data/data_2d_slope.csv', 'w') as f:
    f.write('x1, x2, p_value, h\n')
    for i in range(len(x)):
        f.write("{}, {}, {}, {}\n".format(x[i,0], x[i,1], p[i], h[i]))

# %%
for j in range(1,11):
    n_samples=100000
    p, h, x = generate_data_2D(data_vis=1,n_samples=n_samples, job = 1)
    print("Num of alt: ", np.sum(h))
    print("True null prop: ", 1-np.sum(h)/n_samples)
    dic_BH, t_BH = BH(p)
    print("BH: num of dis, threshold:", dic_BH,t_BH)
    dic_SBH, t_SBH, pi0_SBH = Storey_BH(p)
    print("Storey_BH: num of dis, threshold, null esti", dic_SBH, t_SBH, pi0_SBH)
    plt.savefig('2d1.png')

    with open('../data_rep/data_2d_slope.csv.' + str(j), 'w') as f:
        f.write('x1, x2, p_value, h\n')
        for i in range(len(x)):
            f.write("{}, {}, {}, {}\n".format(x[i,0], x[i,1], p[i], h[i]))
# Out:
# ('Num of alt: ', 19737.0)
# ('True null prop: ', 0.80262999999999995)
# ('BH: num of dis, threshold:', 5704, 0.0028498389725004486)
# ('Storey_BH: num of dis, threshold, null esti', 6343, 0.0038986334888469112, 0.81241666666666668)
# ('Num of alt: ', 19885.0)
# ('True null prop: ', 0.80115000000000003)
# ('BH: num of dis, threshold:', 5957, 0.0029776736456588633)
# ('Storey_BH: num of dis, threshold, null esti', 6598, 0.0040726403673536637, 0.80989999999999995)
# ('Num of alt: ', 20007.0)
# ('True null prop: ', 0.79993000000000003)
# ('BH: num of dis, threshold:', 6032, 0.0030127139905432574)
# ('Storey_BH: num of dis, threshold, null esti', 6680, 0.0041243359542489453, 0.8097833333333333)
# ('Num of alt: ', 19960.0)
# ('True null prop: ', 0.8004)
# ('BH: num of dis, threshold:', 5840, 0.0029184409732832301)
# ('Storey_BH: num of dis, threshold, null esti', 6513, 0.004020603444539991, 0.80886666666666662)
# ('Num of alt: ', 19965.0)
# ('True null prop: ', 0.80035000000000001)
# ('BH: num of dis, threshold:', 6030, 0.0030110814957819976)
# ('Storey_BH: num of dis, threshold, null esti', 6750, 0.0041801452727665295, 0.80725000000000002)
# ('Num of alt: ', 19923.0)
# ('True null prop: ', 0.80076999999999998)
# ('BH: num of dis, threshold:', 5894, 0.0029453230460744296)
# ('Storey_BH: num of dis, threshold, null esti', 6545, 0.0040270317190686453, 0.81246666666666667)
# ('Num of alt: ', 20029.0)
# ('True null prop: ', 0.79971000000000003)
# ('BH: num of dis, threshold:', 6008, 0.003003201548152863)
# ('Storey_BH: num of dis, threshold, null esti', 6729, 0.0041549532219729013, 0.80915000000000004)
# ('Num of alt: ', 19917.0)
# ('True null prop: ', 0.80082999999999993)
# ('BH: num of dis, threshold:', 5879, 0.0029369096662667706)
# ('Storey_BH: num of dis, threshold, null esti', 6582, 0.0040700501209827156, 0.80818333333333336)
# ('Num of alt: ', 20162.0)
# ('True null prop: ', 0.79837999999999998)
# ('BH: num of dis, threshold:', 6235, 0.0031174459488429295)
# ('Storey_BH: num of dis, threshold, null esti', 6970, 0.0043336460256365728, 0.80413333333333337)
# ('Num of alt: ', 19799.0)
# ('True null prop: ', 0.80201)
# ('BH: num of dis, threshold:', 6010, 0.0030045621965775608)
# ('Storey_BH: num of dis, threshold, null esti', 6629, 0.0041117659026122643, 0.80603333333333338)
