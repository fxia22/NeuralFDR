# %%
load("mri.RData")

# %%
library("IHW")
ihw_res <- ihw(output$pval, covariates =  as.factor(output$ROI_labels),  alpha = 0.2)
# Out:
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.

# %%
plot(ihw_res)
# Out:
# plot without title

# %%
rejections(ihw_res)
# Out:
# [1] 918
